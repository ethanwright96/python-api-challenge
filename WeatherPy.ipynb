# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as sts
from scipy.stats import linregress
import datetime

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 652

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %% [markdown]
# ### Use chicago as an example to see data structure

# %%
url = "https://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_api_key

chicago_url = url + "&q=" + "chicago"

chicago_weather = requests.get(chicago_url).json()
chicago_weather
# Out:
# {'coord': {'lon': -87.65, 'lat': 41.85},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 51.3,
#   'feels_like': 48.24,
#   'temp_min': 48.18,
#   'temp_max': 53.37,
#   'pressure': 1019,
#   'humidity': 45},
#  'visibility': 10000,
#  'wind': {'speed': 10.36, 'deg': 180},
#  'clouds': {'all': 20},
#  'dt': 1682605558,
#  'sys': {'type': 2,
#   'id': 2011010,
#   'country': 'US',
#   'sunrise': 1682592751,
#   'sunset': 1682642624},
#  'timezone': -18000,
#  'id': 4887398,
#  'name': 'Chicago',
#  'cod': 200}

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | khatanga
# Processing Record 2 of Set 1 | vanersborg
# Processing Record 3 of Set 1 | banda aceh
# Processing Record 4 of Set 1 | antsohihy
# Processing Record 5 of Set 1 | victoria
# Processing Record 6 of Set 1 | barrow
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | mar del plata
# Processing Record 9 of Set 1 | makung
# City not found. Skipping...
# Processing Record 10 of Set 1 | tuktoyaktuk
# Processing Record 11 of Set 1 | kaitangata
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | manokwari
# Processing Record 16 of Set 1 | georgetown
# Processing Record 17 of Set 1 | new norfolk
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | longyearbyen
# Processing Record 20 of Set 1 | labuhan
# Processing Record 21 of Set 1 | itarema
# Processing Record 22 of Set 1 | port elizabeth
# Processing Record 23 of Set 1 | oriximina
# Processing Record 24 of Set 1 | tura
# Processing Record 25 of Set 1 | iranshahr
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 1 | mahuva
# Processing Record 30 of Set 1 | yulara
# Processing Record 31 of Set 1 | narsaq
# Processing Record 32 of Set 1 | mingaora
# Processing Record 33 of Set 1 | kjollefjord
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | bilibino
# Processing Record 38 of Set 1 | dikson
# Processing Record 39 of Set 1 | yingkou
# Processing Record 40 of Set 1 | tasbuget
# City not found. Skipping...
# Processing Record 41 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | tezu
# Processing Record 44 of Set 1 | san cristobal
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | inongo
# Processing Record 47 of Set 1 | high level
# Processing Record 48 of Set 1 | butaritari
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | urengoy
# Processing Record 0 of Set 2 | hilo
# Processing Record 1 of Set 2 | razole
# Processing Record 2 of Set 2 | minas
# Processing Record 3 of Set 2 | hasaki
# Processing Record 4 of Set 2 | saint-philippe
# Processing Record 5 of Set 2 | tiruchchendur
# Processing Record 6 of Set 2 | chimbote
# Processing Record 7 of Set 2 | trat
# Processing Record 8 of Set 2 | dongsheng
# Processing Record 9 of Set 2 | olafsvik
# Processing Record 10 of Set 2 | port moresby
# Processing Record 11 of Set 2 | kiunga
# Processing Record 12 of Set 2 | east london
# Processing Record 13 of Set 2 | tarko-sale
# Processing Record 14 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 2 | bluff
# Processing Record 16 of Set 2 | temaraia
# City not found. Skipping...
# Processing Record 17 of Set 2 | auki
# Processing Record 18 of Set 2 | montijo
# Processing Record 19 of Set 2 | dhidhdhoo
# Processing Record 20 of Set 2 | fortuna
# Processing Record 21 of Set 2 | tananger
# Processing Record 22 of Set 2 | sao desiderio
# Processing Record 23 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 2 | dingle
# Processing Record 25 of Set 2 | provideniya
# Processing Record 26 of Set 2 | fairbanks
# Processing Record 27 of Set 2 | carnarvon
# Processing Record 28 of Set 2 | juba
# Processing Record 29 of Set 2 | vila franca do campo
# Processing Record 30 of Set 2 | qaanaaq
# Processing Record 31 of Set 2 | vila velha
# Processing Record 32 of Set 2 | kapaa
# Processing Record 33 of Set 2 | sitka
# Processing Record 34 of Set 2 | samarai
# Processing Record 35 of Set 2 | meiktila
# Processing Record 36 of Set 2 | solsvik
# City not found. Skipping...
# Processing Record 37 of Set 2 | upernavik
# Processing Record 38 of Set 2 | lavrentiya
# Processing Record 39 of Set 2 | puerto ayora
# Processing Record 40 of Set 2 | griffith
# Processing Record 41 of Set 2 | cabo san lucas
# Processing Record 42 of Set 2 | guane
# Processing Record 43 of Set 2 | batagay
# Processing Record 44 of Set 2 | touros
# Processing Record 45 of Set 2 | ribeira grande
# Processing Record 46 of Set 2 | airai
# Processing Record 47 of Set 2 | opuwo
# Processing Record 48 of Set 2 | otawara
# Processing Record 49 of Set 2 | san patricio
# Processing Record 0 of Set 3 | weiser
# Processing Record 1 of Set 3 | meiganga
# Processing Record 2 of Set 3 | guerrero negro
# Processing Record 3 of Set 3 | comodoro rivadavia
# Processing Record 4 of Set 3 | manaure
# Processing Record 5 of Set 3 | kushmurun
# Processing Record 6 of Set 3 | richards bay
# Processing Record 7 of Set 3 | altoona
# Processing Record 8 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 3 | ahipara
# Processing Record 10 of Set 3 | santos dumont
# Processing Record 11 of Set 3 | matara
# Processing Record 12 of Set 3 | vaini
# Processing Record 13 of Set 3 | severo-kurilsk
# Processing Record 14 of Set 3 | puerto madryn
# Processing Record 15 of Set 3 | goleniow
# Processing Record 16 of Set 3 | taltal
# Processing Record 17 of Set 3 | starogard gdanski
# Processing Record 18 of Set 3 | viedma
# Processing Record 19 of Set 3 | leningradskiy
# Processing Record 20 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 3 | alampur
# Processing Record 22 of Set 3 | sobolevo
# Processing Record 23 of Set 3 | papayal
# Processing Record 24 of Set 3 | nantucket
# Processing Record 25 of Set 3 | sisimiut
# Processing Record 26 of Set 3 | rock springs
# Processing Record 27 of Set 3 | halifax
# Processing Record 28 of Set 3 | monte carmelo
# Processing Record 29 of Set 3 | hokitika
# Processing Record 30 of Set 3 | srednekolymsk
# Processing Record 31 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 3 | saldanha
# Processing Record 33 of Set 3 | tasiilaq
# Processing Record 34 of Set 3 | pisco
# Processing Record 35 of Set 3 | nikolskoye
# Processing Record 36 of Set 3 | adrar
# Processing Record 37 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 3 | ostrovnoy
# Processing Record 39 of Set 3 | kavaratti
# Processing Record 40 of Set 3 | dipkarpaz
# City not found. Skipping...
# Processing Record 41 of Set 3 | lebu
# Processing Record 42 of Set 3 | mouzakion
# City not found. Skipping...
# Processing Record 43 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 44 of Set 3 | najran
# Processing Record 45 of Set 3 | hammerfest
# Processing Record 46 of Set 3 | majene
# Processing Record 47 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 48 of Set 3 | ixtapa
# Processing Record 49 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 0 of Set 4 | cape town
# Processing Record 1 of Set 4 | ilulissat
# Processing Record 2 of Set 4 | tiznit
# Processing Record 3 of Set 4 | vardo
# Processing Record 4 of Set 4 | solnechnyy
# Processing Record 5 of Set 4 | bilma
# Processing Record 6 of Set 4 | ko samui
# Processing Record 7 of Set 4 | makakilo city
# Processing Record 8 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 4 | cayenne
# Processing Record 10 of Set 4 | mawlaik
# Processing Record 11 of Set 4 | turukhansk
# Processing Record 12 of Set 4 | padang
# Processing Record 13 of Set 4 | san isidro
# Processing Record 14 of Set 4 | paengaroa
# Processing Record 15 of Set 4 | sabzevar
# Processing Record 16 of Set 4 | los llanos de aridane
# Processing Record 17 of Set 4 | hofn
# Processing Record 18 of Set 4 | lichinga
# Processing Record 19 of Set 4 | las vegas
# Processing Record 20 of Set 4 | lanxi
# Processing Record 21 of Set 4 | alofi
# Processing Record 22 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 4 | homer
# Processing Record 24 of Set 4 | chimore
# Processing Record 25 of Set 4 | lakes entrance
# Processing Record 26 of Set 4 | suntar
# Processing Record 27 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 4 | westport
# Processing Record 29 of Set 4 | mandera
# Processing Record 30 of Set 4 | hithadhoo
# Processing Record 31 of Set 4 | saint george
# Processing Record 32 of Set 4 | saint-denis
# Processing Record 33 of Set 4 | antofagasta
# Processing Record 34 of Set 4 | mahebourg
# Processing Record 35 of Set 4 | meybod
# Processing Record 36 of Set 4 | hobart
# Processing Record 37 of Set 4 | saskylakh
# Processing Record 38 of Set 4 | lorengau
# Processing Record 39 of Set 4 | harper
# Processing Record 40 of Set 4 | inuvik
# Processing Record 41 of Set 4 | port augusta
# Processing Record 42 of Set 4 | grindavik
# Processing Record 43 of Set 4 | mariakani
# Processing Record 44 of Set 4 | sault sainte marie
# Processing Record 45 of Set 4 | faya
# Processing Record 46 of Set 4 | vao
# Processing Record 47 of Set 4 | aketi
# Processing Record 48 of Set 4 | santiago de cao
# Processing Record 49 of Set 4 | frontera
# Processing Record 0 of Set 5 | aklavik
# Processing Record 1 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 5 | matagami
# Processing Record 3 of Set 5 | yellowknife
# Processing Record 4 of Set 5 | castro
# Processing Record 5 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 5 | akdepe
# Processing Record 7 of Set 5 | rio grande
# Processing Record 8 of Set 5 | axim
# Processing Record 9 of Set 5 | port alfred
# Processing Record 10 of Set 5 | mbuji-mayi
# Processing Record 11 of Set 5 | tadine
# Processing Record 12 of Set 5 | hualmay
# Processing Record 13 of Set 5 | sao joao da barra
# Processing Record 14 of Set 5 | lagoa
# Processing Record 15 of Set 5 | novoagansk
# Processing Record 16 of Set 5 | gigmoto
# Processing Record 17 of Set 5 | kirakira
# Processing Record 18 of Set 5 | sinkat
# City not found. Skipping...
# Processing Record 19 of Set 5 | aykhal
# Processing Record 20 of Set 5 | tsabong
# Processing Record 21 of Set 5 | constitucion
# Processing Record 22 of Set 5 | iquitos
# Processing Record 23 of Set 5 | necochea
# Processing Record 24 of Set 5 | belaya gora
# Processing Record 25 of Set 5 | quatre cocos
# Processing Record 26 of Set 5 | souillac
# Processing Record 27 of Set 5 | houma
# Processing Record 28 of Set 5 | formosa
# Processing Record 29 of Set 5 | bereda
# Processing Record 30 of Set 5 | katangli
# Processing Record 31 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 5 | talnakh
# Processing Record 33 of Set 5 | nuuk
# Processing Record 34 of Set 5 | port lincoln
# Processing Record 35 of Set 5 | eskilstuna
# Processing Record 36 of Set 5 | ipanguacu
# Processing Record 37 of Set 5 | iwaki
# Processing Record 38 of Set 5 | kargasok
# Processing Record 39 of Set 5 | itambacuri
# Processing Record 40 of Set 5 | bengkulu
# Processing Record 41 of Set 5 | ponta do sol
# Processing Record 42 of Set 5 | udarnyy
# Processing Record 43 of Set 5 | carutapera
# Processing Record 44 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 45 of Set 5 | zhanatas
# City not found. Skipping...
# Processing Record 46 of Set 5 | talara
# Processing Record 47 of Set 5 | chuy
# Processing Record 48 of Set 5 | kosya
# City not found. Skipping...
# Processing Record 49 of Set 5 | raga
# Processing Record 0 of Set 6 | bara
# Processing Record 1 of Set 6 | kamenica
# Processing Record 2 of Set 6 | tiksi
# Processing Record 3 of Set 6 | thompson
# Processing Record 4 of Set 6 | torbay
# Processing Record 5 of Set 6 | jalu
# Processing Record 6 of Set 6 | vitim
# Processing Record 7 of Set 6 | port hardy
# Processing Record 8 of Set 6 | fagersta
# Processing Record 9 of Set 6 | cap malheureux
# Processing Record 10 of Set 6 | kutum
# Processing Record 11 of Set 6 | coleraine
# Processing Record 12 of Set 6 | chokurdakh
# Processing Record 13 of Set 6 | dolores
# Processing Record 14 of Set 6 | yerbogachen
# Processing Record 15 of Set 6 | juxian
# City not found. Skipping...
# Processing Record 16 of Set 6 | caravelas
# Processing Record 17 of Set 6 | cidreira
# Processing Record 18 of Set 6 | nemuro
# Processing Record 19 of Set 6 | san julian
# Processing Record 20 of Set 6 | formosa do rio preto
# Processing Record 21 of Set 6 | svetlyy
# Processing Record 22 of Set 6 | makhinjauri
# Processing Record 23 of Set 6 | sao filipe
# Processing Record 24 of Set 6 | oistins
# Processing Record 25 of Set 6 | murdochville
# Processing Record 26 of Set 6 | kualakapuas
# Processing Record 27 of Set 6 | vanimo
# Processing Record 28 of Set 6 | preston
# Processing Record 29 of Set 6 | mackay
# Processing Record 30 of Set 6 | bowen
# Processing Record 31 of Set 6 | levelland
# Processing Record 32 of Set 6 | kushnarenkovo
# Processing Record 33 of Set 6 | dalvik
# Processing Record 34 of Set 6 | payo
# Processing Record 35 of Set 6 | varese
# Processing Record 36 of Set 6 | strezhevoy
# Processing Record 37 of Set 6 | zalesovo
# Processing Record 38 of Set 6 | the pas
# Processing Record 39 of Set 6 | casper
# Processing Record 40 of Set 6 | ponerihouen
# Processing Record 41 of Set 6 | saint anthony
# Processing Record 42 of Set 6 | tateyama
# Processing Record 43 of Set 6 | sao bernardo
# Processing Record 44 of Set 6 | belmonte
# Processing Record 45 of Set 6 | anadyr
# Processing Record 46 of Set 6 | chapais
# Processing Record 47 of Set 6 | lysyye gory
# Processing Record 48 of Set 6 | fukue
# Processing Record 49 of Set 6 | maiduguri
# Processing Record 0 of Set 7 | merauke
# Processing Record 1 of Set 7 | arraial do cabo
# Processing Record 2 of Set 7 | tuatapere
# Processing Record 3 of Set 7 | dunedin
# Processing Record 4 of Set 7 | broome
# Processing Record 5 of Set 7 | lata
# Processing Record 6 of Set 7 | pemba
# Processing Record 7 of Set 7 | coruripe
# Processing Record 8 of Set 7 | maltahohe
# Processing Record 9 of Set 7 | krasnyy chikoy
# Processing Record 10 of Set 7 | opatija
# Processing Record 11 of Set 7 | ust-ishim
# Processing Record 12 of Set 7 | hohhot
# Processing Record 13 of Set 7 | hat yai
# Processing Record 14 of Set 7 | cherskiy
# Processing Record 15 of Set 7 | zhigansk
# Processing Record 16 of Set 7 | pandan
# Processing Record 17 of Set 7 | codrington
# Processing Record 18 of Set 7 | ha tinh
# Processing Record 19 of Set 7 | roald
# Processing Record 20 of Set 7 | tabas
# Processing Record 21 of Set 7 | omaruru
# Processing Record 22 of Set 7 | port shepstone
# Processing Record 23 of Set 7 | bokovskaya
# Processing Record 24 of Set 7 | azul
# Processing Record 25 of Set 7 | nanortalik
# Processing Record 26 of Set 7 | kiruna
# Processing Record 27 of Set 7 | bubaque
# Processing Record 28 of Set 7 | klaksvik
# Processing Record 29 of Set 7 | bambanglipuro
# Processing Record 30 of Set 7 | asfi
# Processing Record 31 of Set 7 | izumo
# Processing Record 32 of Set 7 | kurumkan
# Processing Record 33 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 34 of Set 7 | ulaanbaatar
# Processing Record 35 of Set 7 | teahupoo
# Processing Record 36 of Set 7 | kavieng
# Processing Record 37 of Set 7 | altay
# Processing Record 38 of Set 7 | great yarmouth
# Processing Record 39 of Set 7 | miandrivazo
# Processing Record 40 of Set 7 | shimoda
# Processing Record 41 of Set 7 | teya
# Processing Record 42 of Set 7 | coquimbo
# Processing Record 43 of Set 7 | beyneu
# Processing Record 44 of Set 7 | vangaindrano
# Processing Record 45 of Set 7 | laguna
# Processing Record 46 of Set 7 | salalah
# Processing Record 47 of Set 7 | soyo
# Processing Record 48 of Set 7 | ampanihy
# Processing Record 49 of Set 7 | scarborough
# Processing Record 0 of Set 8 | saint-joseph
# Processing Record 1 of Set 8 | bukama
# Processing Record 2 of Set 8 | havelock
# Processing Record 3 of Set 8 | esperance
# Processing Record 4 of Set 8 | soure
# Processing Record 5 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 6 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 8 | sangar
# Processing Record 8 of Set 8 | una
# Processing Record 9 of Set 8 | cetraro
# Processing Record 10 of Set 8 | yaan
# Processing Record 11 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 8 | canton
# Processing Record 13 of Set 8 | luanda
# Processing Record 14 of Set 8 | zhireken
# Processing Record 15 of Set 8 | xunchang
# Processing Record 16 of Set 8 | fergus
# Processing Record 17 of Set 8 | kabanjahe
# Processing Record 18 of Set 8 | gold coast
# Processing Record 19 of Set 8 | lokosovo
# Processing Record 20 of Set 8 | tayginka
# Processing Record 21 of Set 8 | ambon
# Processing Record 22 of Set 8 | mount isa
# Processing Record 23 of Set 8 | kahului
# Processing Record 24 of Set 8 | kodiak
# Processing Record 25 of Set 8 | worcester
# Processing Record 26 of Set 8 | broken hill
# Processing Record 27 of Set 8 | norman wells
# Processing Record 28 of Set 8 | severnoye
# Processing Record 29 of Set 8 | darlawn
# Processing Record 30 of Set 8 | newport
# Processing Record 31 of Set 8 | hobyo
# Processing Record 32 of Set 8 | dordrecht
# Processing Record 33 of Set 8 | acari
# Processing Record 34 of Set 8 | upington
# Processing Record 35 of Set 8 | daru
# Processing Record 36 of Set 8 | tuy hoa
# Processing Record 37 of Set 8 | bahir dar
# Processing Record 38 of Set 8 | khromtau
# Processing Record 39 of Set 8 | plouzane
# Processing Record 40 of Set 8 | kalmar
# Processing Record 41 of Set 8 | sorong
# Processing Record 42 of Set 8 | burica
# City not found. Skipping...
# Processing Record 43 of Set 8 | acapulco
# Processing Record 44 of Set 8 | mount pleasant
# Processing Record 45 of Set 8 | bundaberg
# Processing Record 46 of Set 8 | marienburg
# Processing Record 47 of Set 8 | granja
# Processing Record 48 of Set 8 | kovur
# Processing Record 49 of Set 8 | hay river
# Processing Record 0 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 9 | pevek
# Processing Record 2 of Set 9 | rocha
# Processing Record 3 of Set 9 | la ronge
# Processing Record 4 of Set 9 | kollumerland
# City not found. Skipping...
# Processing Record 5 of Set 9 | port-gentil
# Processing Record 6 of Set 9 | namatanai
# Processing Record 7 of Set 9 | manbij
# Processing Record 8 of Set 9 | santona
# Processing Record 9 of Set 9 | roma
# Processing Record 10 of Set 9 | canutama
# Processing Record 11 of Set 9 | baykit
# Processing Record 12 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 9 | iqaluit
# Processing Record 14 of Set 9 | faanui
# Processing Record 15 of Set 9 | maku
# Processing Record 16 of Set 9 | lethem
# Processing Record 17 of Set 9 | pringsewu
# Processing Record 18 of Set 9 | luderitz
# Processing Record 19 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 20 of Set 9 | kasama
# Processing Record 21 of Set 9 | mount gambier
# Processing Record 22 of Set 9 | abu dhabi
# Processing Record 23 of Set 9 | falun
# Processing Record 24 of Set 9 | palmer
# Processing Record 25 of Set 9 | kudymkar
# Processing Record 26 of Set 9 | katsuura
# Processing Record 27 of Set 9 | pangkalanbuun
# Processing Record 28 of Set 9 | zhiryatino
# Processing Record 29 of Set 9 | geraldton
# Processing Record 30 of Set 9 | byron bay
# Processing Record 31 of Set 9 | katherine
# Processing Record 32 of Set 9 | simbahan
# Processing Record 33 of Set 9 | nokaneng
# Processing Record 34 of Set 9 | saiha
# Processing Record 35 of Set 9 | atambua
# Processing Record 36 of Set 9 | senanga
# Processing Record 37 of Set 9 | makushino
# Processing Record 38 of Set 9 | kvitok
# Processing Record 39 of Set 9 | prince george
# Processing Record 40 of Set 9 | vigia del fuerte
# Processing Record 41 of Set 9 | kapit
# Processing Record 42 of Set 9 | nouadhibou
# Processing Record 43 of Set 9 | jeremie
# Processing Record 44 of Set 9 | funadhoo
# Processing Record 45 of Set 9 | den helder
# Processing Record 46 of Set 9 | jinchengjiang
# City not found. Skipping...
# Processing Record 47 of Set 9 | monte san pietro
# Processing Record 48 of Set 9 | zhezkazgan
# Processing Record 49 of Set 9 | tashtyp
# Processing Record 0 of Set 10 | porto walter
# Processing Record 1 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 10 | kieta
# Processing Record 3 of Set 10 | svetlogorsk
# Processing Record 4 of Set 10 | dixon
# Processing Record 5 of Set 10 | margate
# Processing Record 6 of Set 10 | komsomolskiy
# Processing Record 7 of Set 10 | thinadhoo
# Processing Record 8 of Set 10 | qaqortoq
# Processing Record 9 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 10 | qianan
# Processing Record 11 of Set 10 | maarianhamina
# Processing Record 12 of Set 10 | fomboni
# Processing Record 13 of Set 10 | saint-pierre
# Processing Record 14 of Set 10 | port-cartier
# Processing Record 15 of Set 10 | lasa
# Processing Record 16 of Set 10 | chute-aux-outardes
# Processing Record 17 of Set 10 | coahuayana
# Processing Record 18 of Set 10 | cordoba
# Processing Record 19 of Set 10 | narok
# Processing Record 20 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 10 | vagur
# Processing Record 22 of Set 10 | bac lieu
# Processing Record 23 of Set 10 | hambantota
# Processing Record 24 of Set 10 | parli
# Processing Record 25 of Set 10 | buala
# Processing Record 26 of Set 10 | alyangula
# Processing Record 27 of Set 10 | conceicao do araguaia
# Processing Record 28 of Set 10 | xai-xai
# Processing Record 29 of Set 10 | dutlwe
# Processing Record 30 of Set 10 | ust-donetskiy
# Processing Record 31 of Set 10 | flin flon
# Processing Record 32 of Set 10 | mariinsk
# Processing Record 33 of Set 10 | minna
# Processing Record 34 of Set 10 | bartica
# Processing Record 35 of Set 10 | xingyi
# Processing Record 36 of Set 10 | arkhipo-osipovka
# Processing Record 37 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 38 of Set 10 | copiapo
# Processing Record 39 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 10 | port macquarie
# Processing Record 41 of Set 10 | omsukchan
# Processing Record 42 of Set 10 | kushiro
# Processing Record 43 of Set 10 | meadow lake
# Processing Record 44 of Set 10 | araouane
# Processing Record 45 of Set 10 | avera
# Processing Record 46 of Set 10 | nicoya
# Processing Record 47 of Set 10 | inzer
# Processing Record 48 of Set 10 | colomiers
# Processing Record 49 of Set 10 | london
# Processing Record 0 of Set 11 | inirida
# Processing Record 1 of Set 11 | benjamin aceval
# Processing Record 2 of Set 11 | alta
# Processing Record 3 of Set 11 | rodeo
# Processing Record 4 of Set 11 | derzhavinsk
# Processing Record 5 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 6 of Set 11 | filingue
# Processing Record 7 of Set 11 | nyurba
# Processing Record 8 of Set 11 | washington
# Processing Record 9 of Set 11 | sakaraha
# Processing Record 10 of Set 11 | esil
# Processing Record 11 of Set 11 | romny
# Processing Record 12 of Set 11 | berlevag
# Processing Record 13 of Set 11 | kruisfontein
# Processing Record 14 of Set 11 | marawi
# Processing Record 15 of Set 11 | volchansk
# Processing Record 16 of Set 11 | waipawa
# Processing Record 17 of Set 11 | ust-tarka
# Processing Record 18 of Set 11 | pangnirtung
# Processing Record 19 of Set 11 | balkanabat
# Processing Record 20 of Set 11 | kaka
# Processing Record 21 of Set 11 | bambous virieux
# Processing Record 22 of Set 11 | khani
# Processing Record 23 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 24 of Set 11 | dharmanagar
# Processing Record 25 of Set 11 | wasilla
# Processing Record 26 of Set 11 | ponta delgada
# Processing Record 27 of Set 11 | marsh harbour
# Processing Record 28 of Set 11 | impfondo
# Processing Record 29 of Set 11 | nelson bay
# Processing Record 30 of Set 11 | bennettsville
# Processing Record 31 of Set 11 | puerto escondido
# Processing Record 32 of Set 11 | camacha
# Processing Record 33 of Set 11 | ahuimanu
# Processing Record 34 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 35 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 36 of Set 11 | vytegra
# Processing Record 37 of Set 11 | narasannapeta
# Processing Record 38 of Set 11 | banff
# Processing Record 39 of Set 11 | kirksville
# Processing Record 40 of Set 11 | tamala
# Processing Record 41 of Set 11 | ken caryl
# Processing Record 42 of Set 11 | mirina
# City not found. Skipping...
# Processing Record 43 of Set 11 | carballo
# Processing Record 44 of Set 11 | hamilton
# Processing Record 45 of Set 11 | egvekinot
# Processing Record 46 of Set 11 | mareeba
# Processing Record 47 of Set 11 | muisne
# Processing Record 48 of Set 11 | paamiut
# Processing Record 49 of Set 11 | port hedland
# Processing Record 0 of Set 12 | wanning
# Processing Record 1 of Set 12 | dzerzhinskoye
# Processing Record 2 of Set 12 | ayan
# Processing Record 3 of Set 12 | nata
# Processing Record 4 of Set 12 | upata
# Processing Record 5 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 6 of Set 12 | pochutla
# Processing Record 7 of Set 12 | edson
# Processing Record 8 of Set 12 | vostok
# Processing Record 9 of Set 12 | naze
# Processing Record 10 of Set 12 | mikhaylovskoye
# Processing Record 11 of Set 12 | roros
# Processing Record 12 of Set 12 | yuncheng
# Processing Record 13 of Set 12 | isangel
# Processing Record 14 of Set 12 | huilong
# Processing Record 15 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 12 | uyuni
# Processing Record 17 of Set 12 | ukiah
# Processing Record 18 of Set 12 | salmas
# Processing Record 19 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 12 | cabedelo
# Processing Record 21 of Set 12 | awjilah
# Processing Record 22 of Set 12 | sao miguel do tapuio
# Processing Record 23 of Set 12 | kasongo-lunda
# Processing Record 24 of Set 12 | rovaniemi
# Processing Record 25 of Set 12 | nizhniy odes
# Processing Record 26 of Set 12 | daitari
# Processing Record 27 of Set 12 | san jose de guanipa
# Processing Record 28 of Set 12 | alekseyevskoye
# Processing Record 29 of Set 12 | trindade
# Processing Record 30 of Set 12 | vestmannaeyjar
# Processing Record 31 of Set 12 | basco
# Processing Record 32 of Set 12 | ugento
# Processing Record 33 of Set 12 | jalor
# Processing Record 34 of Set 12 | meulaboh
# Processing Record 35 of Set 12 | adre
# Processing Record 36 of Set 12 | cornwall
# Processing Record 37 of Set 12 | zyryanka
# Processing Record 38 of Set 12 | clyde river
# Processing Record 39 of Set 12 | west wendover
# Processing Record 40 of Set 12 | le port
# Processing Record 41 of Set 12 | karratha
# Processing Record 42 of Set 12 | itoman
# Processing Record 43 of Set 12 | santa maria
# Processing Record 44 of Set 12 | eyl
# Processing Record 45 of Set 12 | valpacos
# Processing Record 46 of Set 12 | adelaide
# Processing Record 47 of Set 12 | sapao
# City not found. Skipping...
# Processing Record 48 of Set 12 | biloela
# Processing Record 49 of Set 12 | maragogi
# Processing Record 0 of Set 13 | tumut
# Processing Record 1 of Set 13 | san rafael
# Processing Record 2 of Set 13 | golspie
# Processing Record 3 of Set 13 | rio gallegos
# Processing Record 4 of Set 13 | bolshiye kaybitsy
# City not found. Skipping...
# Processing Record 5 of Set 13 | visby
# Processing Record 6 of Set 13 | yian
# City not found. Skipping...
# Processing Record 7 of Set 13 | skjervoy
# Processing Record 8 of Set 13 | pyapon
# Processing Record 9 of Set 13 | semenivka
# Processing Record 10 of Set 13 | sao francisco
# Processing Record 11 of Set 13 | marzuq
# Processing Record 12 of Set 13 | ishigaki
# Processing Record 13 of Set 13 | warrington
# Processing Record 14 of Set 13 | nove zamky
# Processing Record 15 of Set 13 | victor harbor
# Processing Record 16 of Set 13 | magadan
# Processing Record 17 of Set 13 | wagga wagga
# Processing Record 18 of Set 13 | beloha
# Processing Record 19 of Set 13 | karanja
# Processing Record 20 of Set 13 | raymondville
# Processing Record 21 of Set 13 | ancud
# Processing Record 22 of Set 13 | payson
# Processing Record 23 of Set 13 | araripe
# Processing Record 24 of Set 13 | kamaishi
# Processing Record 25 of Set 13 | sola
# Processing Record 26 of Set 13 | boca do acre
# Processing Record 27 of Set 13 | ballina
# Processing Record 28 of Set 13 | umm lajj
# Processing Record 29 of Set 13 | haines junction
# Processing Record 30 of Set 13 | datong
# Processing Record 31 of Set 13 | kidal
# Processing Record 32 of Set 13 | tual
# Processing Record 33 of Set 13 | tra vinh
# Processing Record 34 of Set 13 | honiara
# Processing Record 35 of Set 13 | nohfelden
# Processing Record 36 of Set 13 | iquique
# Processing Record 37 of Set 13 | laredo
# Processing Record 38 of Set 13 | perleberg
# Processing Record 39 of Set 13 | huntington
# Processing Record 40 of Set 13 | evensk
# Processing Record 41 of Set 13 | hami
# Processing Record 42 of Set 13 | aksu
# Processing Record 43 of Set 13 | caucaia
# Processing Record 44 of Set 13 | umm kaddadah
# Processing Record 45 of Set 13 | rzhaksa
# Processing Record 46 of Set 13 | chernyshevskiy
# Processing Record 47 of Set 13 | sorland
# Processing Record 48 of Set 13 | eureka
# Processing Record 49 of Set 13 | surt
# Processing Record 0 of Set 14 | lunino
# Processing Record 1 of Set 14 | noyabrsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          598
# Lat           598
# Lng           598
# Max Temp      598
# Humidity      598
# Cloudiness    598
# Wind Speed    598
# Country       598
# Date          598
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    khatanga  71.9667  102.5000     18.50        94          43        8.84
# 1  vanersborg  58.3807   12.3234     51.91        34           0       17.27
# 2  banda aceh   5.5577   95.3222     81.55        79         100        5.08
# 3   antsohihy -14.8796   47.9875     83.14        65          46        5.44
# 4    victoria  22.2855  114.1577     73.96        89          86       13.00
#
#   Country        Date
# 0      RU  1682606089
# 1      SE  1682606090
# 2      ID  1682606090
# 3      MG  1682606090
# 4      HK  1682606029

# %% [markdown]
# ### Convert timestamp to yyyy/mm/dd date

# %%
date = datetime.date.fromtimestamp(1682606089)
date_printed = print(date)
date_printed
# Out:
# 2023-04-27

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          khatanga  71.9667  102.5000     18.50        94          43
# 1        vanersborg  58.3807   12.3234     51.91        34           0
# 2        banda aceh   5.5577   95.3222     81.55        79         100
# 3         antsohihy -14.8796   47.9875     83.14        65          46
# 4          victoria  22.2855  114.1577     73.96        89          86
#
#          Wind Speed Country        Date
# City_ID
# 0              8.84      RU  1682606089
# 1             17.27      SE  1682606090
# 2              5.08      ID  1682606090
# 3              5.44      MG  1682606090
# 4             13.00      HK  1682606029

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

latitude = city_data_df['Lat']
max_temp = city_data_df['Max Temp']

plt.scatter(x=latitude, y=max_temp, color = 'lightblue', edgecolor = 'black')

# Incorporate the other graph properties
plt.title("City Max Temperature vs. Latitude (2023-04-27)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity

latitude = city_data_df['Lat']
humidity = city_data_df['Humidity']

plt.scatter(x=latitude, y=humidity, color = 'orange', edgecolor = 'black')

# Incorporate the other graph properties
plt.title("City Humidity vs. Latitude (2023-04-27)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
latitude = city_data_df['Lat']
cloudiness = city_data_df['Cloudiness']

plt.scatter(x=latitude, y=cloudiness, color = 'purple', edgecolor = 'black')

# Incorporate the other graph properties
plt.title("City Cloudiness (%) vs. Latitude (2023-04-27)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed

latitude = city_data_df['Lat']
wind_speed = city_data_df['Wind Speed']

plt.scatter(x=latitude, y=wind_speed, color = 'magenta', edgecolor = 'black')

# Incorporate the other graph properties
plt.title("City Wind Speed vs. Latitude (2023-04-27)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %% [markdown]
# ### The arguments of the linear regression plot functions are: x (independent variable), y (dependent variable), annotate_x (x coordinate of annotation), annotate_y (y coordinate of annotation), title, xlabel, & ylabel

# %%
# Define a function to create Linear Regression plots

def lin_reg_plot(x,y,annotate_x,annotate_y,title,xlabel,ylabel):
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    plt.annotate(line_eq,(annotate_x,annotate_y),fontsize=15,color="red")
    plt.title(f"{title}")
    plt.xlabel(f"{xlabel}")
    plt.ylabel(f"{ylabel}")
    plt.show()

# %%
### Test linear regression scatter plot function on wind speed and latitude
lin_reg_plot(city_data_df['Lat'], city_data_df['Wind Speed'],-10,30,"City Wind Speed by Latitude","Latitude","Wind Speed (m/s)")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          khatanga  71.9667  102.5000     18.50        94          43
# 1        vanersborg  58.3807   12.3234     51.91        34           0
# 2        banda aceh   5.5577   95.3222     81.55        79         100
# 4          victoria  22.2855  114.1577     73.96        89          86
# 5            barrow  71.2906 -156.7887      1.42        85           0
#
#          Wind Speed Country        Date
# City_ID
# 0              8.84      RU  1682606089
# 1             17.27      SE  1682606090
# 2              5.08      ID  1682606090
# 4             13.00      HK  1682606029
# 5             13.80      US  1682606090

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3            antsohihy -14.8796   47.9875     83.14        65          46
# 6              rikitea -23.1203 -134.9692     74.55        64          96
# 7        mar del plata -38.0023  -57.5575     67.82        75          40
# 9           kaitangata -46.2817  169.8464     47.25        94           6
# 10        punta arenas -53.1500  -70.9167     44.71        70          20
#
#          Wind Speed Country        Date
# City_ID
# 3              5.44      MG  1682606090
# 6              6.17      PF  1682606091
# 7              5.75      AR  1682606063
# 9              2.42      NZ  1682606091
# 10            31.07      CL  1682605943

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
lin_reg_plot(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'],47,75,"City Max Temperature by Latitude (Northern Hemisphere)","Latitude","Max Temperature (F)")

# %%
x = northern_hemi_df['Lat']
y = northern_hemi_df['Max Temp']
res = sts.linregress(x, y)
print(f"R-squared: {res.rvalue**2:.6f}")
# Out:
# R-squared: 0.724385

# %%
# Linear regression on Southern Hemisphere
lin_reg_plot(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'],-50,45,"City Max Temperature by Latitude (Southern Hemisphere)","Latitude","Max Temperature (F)")

# %%
x = southern_hemi_df['Lat']
y = southern_hemi_df['Max Temp']
res = sts.linregress(x, y)
print(f"R-squared: {res.rvalue**2:.6f}")
# Out:
# R-squared: 0.529930

# %% [markdown]
# **Discussion about the linear relationship:**

# %% [markdown]
# ### There is a linear relationship between Latitude and Maximum Temperature in both the Northern and Southern Hemispheres. A Latitude of 0 denotes the Earth's equator. In the Northern Hemisphere, the slope of the line of best fit is -.98, meaning that for every degree N of the equator, Max Temperature climbs almost an entire degree (F). In the Southern Hemisphere, the slope of the line of best fit is .53, meaning that for every degree S of the equator, Max Temperature climbs approximately half a degree (F). With R-Squared values of .72 and .53 respectively (N and S), the former would be considered strong and the latter: marginally strong. It's curious that these two linear models are not simply each other's mirror image. Without much speculation, it's plausible that this has to do with the Earth's axial tilt (23.5 degrees).

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_reg_plot(northern_hemi_df['Lat'], northern_hemi_df['Humidity'],45,10,"City Humidity by Latitude (Northern Hemisphere)","Latitude","Humidity (%)")

# %%
x = northern_hemi_df['Lat']
y = northern_hemi_df['Humidity']
res = sts.linregress(x, y)
print(f"R-squared: {res.rvalue**2:.6f}")
# Out:
# R-squared: 0.074596

# %%
# Southern Hemisphere
lin_reg_plot(southern_hemi_df['Lat'], southern_hemi_df['Humidity'],-55,20,"City Humidity by Latitude (Southern Hemisphere)","Latitude","Humidity (%)")

# %%
x = southern_hemi_df['Lat']
y = southern_hemi_df['Humidity']
res = sts.linregress(x, y)
print(f"R-squared: {res.rvalue**2:.6f}")
# Out:
# R-squared: 0.035235

# %% [markdown]
# **Discussion about the linear relationship:**

# %% [markdown]
# ### There is a weak linear relationship between Latitude and Humidity in both the Northern and Southern Hemispheres. The slope of the lines of best fit are .31 and .27 respectively. Both models' R-squared values, .07 and .04, imply that latitude may be one of several factors that affect humidity, but it in it of itself does not fully explain humidity in either hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_reg_plot(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'],40,50,"City Cloudiness by Latitude (Northern Hemisphere)","Latitude","Cloudiness")

# %%
x = northern_hemi_df['Lat']
y = northern_hemi_df['Cloudiness']
res = sts.linregress(x, y)
print(f"R-squared: {res.rvalue**2:.6f}")
# Out:
# R-squared: 0.013389

# %%
# Southern Hemisphere
lin_reg_plot(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'],-55,55,"City Cloudiness by Latitude (Southern Hemisphere)","Latitude","Cloudiness")

# %%
x = southern_hemi_df['Lat']
y = southern_hemi_df['Cloudiness']
res = sts.linregress(x, y)
print(f"R-squared: {res.rvalue**2:.6f}")
# Out:
# R-squared: 0.091050

# %% [markdown]
# **Discussion about the linear relationship:**

# %% [markdown]
# ### There is a stronger linear relationship between Cloudiness and Latitude in the Southern Hemisphere than there is in the Northern (line slopes of .86 and .22 respectively). Interestingly, in the Northern hemisphere, it appears that the father a city is from the equator, the cloudier it is. Whereas in the Southern Hemisphere, the closer a city is to the equator the cloudier it is. However, in both cases, the R-squared value is particularly small, implying that Latitude is far from a perfect predictor of Cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
lin_reg_plot(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'],0,25,"City Wind Speed by Latitude (Northern Hemisphere)","Latitude","Wind Speed (m/s)")

# %%
x = northern_hemi_df['Lat']
y = northern_hemi_df['Wind Speed']
res = sts.linregress(x, y)
print(f"R-squared: {res.rvalue**2:.6f}")
# Out:
# R-squared: 0.010346

# %%
# Southern Hemisphere
lin_reg_plot(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'],-55,18,"City Wind Speed by Latitude (Southern Hemisphere)","Latitude","Wind Speed (m/s)")

# %%
x = southern_hemi_df['Lat']
y = southern_hemi_df['Wind Speed']
res = sts.linregress(x, y)
print(f"R-squared: {res.rvalue**2:.6f}")
# Out:
# R-squared: 0.130519

# %% [markdown]
# **Discussion about the linear relationship:**

# %% [markdown]
# ### Among the variables analyzed thus far, Latitude and Wind Speed show the weakest linear relationship with the Northern Hemisphere having close to zero relationship at all (m = .03). In the Southern Hemisphere, the data show a slight negative correlation (m = -.15), meaning that Wind Speed increases as City's move away from the equator.
